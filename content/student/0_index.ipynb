# %% [markdown]
# # Index - Topology optimization tutorial
#
# ## Tutorial notebooks
#
# -1) [FEM forward problem](1_FEM_forward_problem.ipynb)
#
# -2) [Topology optimization with density method (SIMP)](2_SIMP.ipynb)
#
# -3) [Topology optimization with homogenization](3_homogenization.ipynb)
#
# -4a) [Crisp methods : BESO](4a_BESO.ipynb)
#
# -4b) [Crisp methods : level-set topology optimization + topological derivative](4b_Topological_derivative.ipynb)
# ___
# ## Appendix
#
# - [A) Jupyter cheat sheet](A_Jupyter_cheat_sheet.ipynb)
# - [B) NGSolve cheat sheet](B_NGSolve_cheat_sheet.ipynb)
